# %%
# !pip install zipfile36
from zipfile import ZipFile


def unzip(file_path):
    """Unzips the file located at file_path to the current directory."""
    with ZipFile(file_path, 'r') as zip_ref:
        zip_ref.extractall(".")


zip_file_path = "/content/drive/MyDrive/AI_ML_WorkShop_4/Copy of devnagari digit.zip"
# Out:
# Collecting zipfile36
#   Downloading zipfile36-0.1.3-py3-none-any.whl.metadata (736 bytes)
# Downloading zipfile36-0.1.3-py3-none-any.whl (20 kB)
# Installing collected packages: zipfile36
# Successfully installed zipfile36-0.1.3

# %%
unzip(zip_file_path)

# %%
import tensorflow as tf
print(tf.keras.__version__)
# Out:
# 3.8.0

# %%
import numpy as np
# Simple function f(x) = x^2
def f(x):
 return x ** 2
# Manual derivative (f’(x) = 2x)
def gradient(x):
 return 2 * x
# Update rule: x = x - learning_rate * gradient
x = 5.0
learning_rate = 0.1
for _ in range(10): # Manually optimize for 10 steps
  x -= learning_rate * gradient(x)
  print(f"x: {x}, f(x): {f(x)}")
# Out:
# x: 4.0, f(x): 16.0
# x: 3.2, f(x): 10.240000000000002
# x: 2.56, f(x): 6.5536
# x: 2.048, f(x): 4.194304
# x: 1.6384, f(x): 2.68435456
# x: 1.31072, f(x): 1.7179869184000003
# x: 1.0485760000000002, f(x): 1.0995116277760004
# x: 0.8388608000000002, f(x): 0.7036874417766403
# x: 0.6710886400000001, f(x): 0.45035996273704976
# x: 0.5368709120000001, f(x): 0.2882303761517119

# %%
import tensorflow as tf
x = tf.Variable(5.0) # Trainable variable
with tf.GradientTape() as tape:
   y = x ** 2 # y = x^2
grad = tape.gradient(y, x) # Computes dy/dx automatically
print(grad.numpy()) # Output: 10.0
# Out:
# 10.0

# %%
import numpy as np
import tensorflow as tf
import time
# Create large random matrices
size = (1000, 1000)
A = np.random.rand(*size)
B = np.random.rand(*size)
# NumPy Multiplication
start = time.time()
C_numpy = np.dot(A, B)
print("NumPy Time:", time.time() - start)
# TensorFlow Multiplication (for colab uses GPU Runtime if available)
A_tf = tf.constant(A)
B_tf = tf.constant(B)
start = time.time()
C_tf = tf.matmul(A_tf, B_tf)
print("TensorFlow Time:", time.time() - start)
# Out:
# NumPy Time: 0.04532599449157715
# TensorFlow Time: 0.1125943660736084

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import mnist
# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Normalize the images to values between 0 and 1
x_train, x_test = x_train / 255.0, x_test / 255.0
# Flatten the 28x28 images into 784-dimensional vectors
x_train = x_train.reshape(-1, 28 * 28)
x_test = x_test.reshape(-1, 28 * 28)
# One-hot encode the labels (0-9) for classification
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Model parameters
import tensorflow as tf
from tensorflow import keras
num_classes = 10
input_shape = (28*28,)
model = keras.Sequential(
[
keras.layers.Input(shape=input_shape),
keras.layers.Flatten(), # Flatten the 28x28 image to a 784-dimensional vector
keras.layers.Dense(64, activation="sigmoid"),
keras.layers.Dense(128, activation="sigmoid"),
keras.layers.Dense(256, activation="sigmoid"),
keras.layers.Dense(num_classes, activation="softmax"),
]
)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │          50,240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 256)                 │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 10)                  │           2,570 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 94,154 (367.79 KB)
#  Trainable params: 94,154 (367.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
optimizer="sgd", # Stochastic Gradient Descent
loss="categorical_crossentropy", # Loss function for multi-class classification
metrics=["accuracy"] # Track accuracy during training
)

# %%
batch_size = 128
epochs = 2000
# Callbacks
callbacks = [
keras.callbacks.ModelCheckpoint(filepath="model_at_epoch_{epoch}.keras"),
keras.callbacks.EarlyStopping(monitor="val_loss", patience=4 ),
]
# Train the model with callbacks and validation split
history = model.fit(
  x_train,
  y_train,
  batch_size=batch_size,
  epochs=epochs,
  validation_split=0.15,
  callbacks=callbacks,)
# Out:
# Epoch 1/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.1061 - loss: 2.3439 - val_accuracy: 0.1063 - val_loss: 2.3021
# Epoch 2/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1103 - loss: 2.3022 - val_accuracy: 0.1063 - val_loss: 2.3033
# Epoch 3/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.1136 - loss: 2.3017 - val_accuracy: 0.1063 - val_loss: 2.3012
# Epoch 4/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.1177 - loss: 2.2998 - val_accuracy: 0.1063 - val_loss: 2.2997
# Epoch 5/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.1183 - loss: 2.2990 - val_accuracy: 0.1226 - val_loss: 2.2986
# Epoch 6/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1175 - loss: 2.2979 - val_accuracy: 0.1524 - val_loss: 2.2971
# Epoch 7/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1215 - loss: 2.2958 - val_accuracy: 0.1063 - val_loss: 2.2956
# Epoch 8/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1220 - loss: 2.2946 - val_accuracy: 0.1063 - val_loss: 2.2942
# Epoch 9/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1249 - loss: 2.2934 - val_accuracy: 0.1551 - val_loss: 2.2930
# Epoch 10/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1297 - loss: 2.2913 - val_accuracy: 0.1063 - val_loss: 2.2898
# Epoch 11/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1370 - loss: 2.2891 - val_accuracy: 0.1063 - val_loss: 2.2878
# Epoch 12/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1282 - loss: 2.2865 - val_accuracy: 0.1063 - val_loss: 2.2840
# Epoch 13/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1347 - loss: 2.2841 - val_accuracy: 0.1063 - val_loss: 2.2827
# Epoch 14/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1528 - loss: 2.2812 - val_accuracy: 0.2020 - val_loss: 2.2784
# Epoch 15/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.1636 - loss: 2.2770 - val_accuracy: 0.1036 - val_loss: 2.2748
# Epoch 16/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1763 - loss: 2.2732 - val_accuracy: 0.3648 - val_loss: 2.2696
# Epoch 17/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2228 - loss: 2.2677 - val_accuracy: 0.1929 - val_loss: 2.2621
# Epoch 18/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2668 - loss: 2.2614 - val_accuracy: 0.1560 - val_loss: 2.2554
# Epoch 19/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2200 - loss: 2.2518 - val_accuracy: 0.3011 - val_loss: 2.2439
# Epoch 20/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3041 - loss: 2.2423 - val_accuracy: 0.2274 - val_loss: 2.2339
# Epoch 21/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2738 - loss: 2.2279 - val_accuracy: 0.4628 - val_loss: 2.2138
# Epoch 22/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3644 - loss: 2.2114 - val_accuracy: 0.4794 - val_loss: 2.1918
# Epoch 23/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3760 - loss: 2.1865 - val_accuracy: 0.3089 - val_loss: 2.1619
# Epoch 24/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3905 - loss: 2.1556 - val_accuracy: 0.4389 - val_loss: 2.1208
# Epoch 25/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4114 - loss: 2.1105 - val_accuracy: 0.4096 - val_loss: 2.0651
# Epoch 26/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4136 - loss: 2.0491 - val_accuracy: 0.3872 - val_loss: 1.9890
# Epoch 27/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4204 - loss: 1.9716 - val_accuracy: 0.4458 - val_loss: 1.8946
# Epoch 28/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4609 - loss: 1.8748 - val_accuracy: 0.4878 - val_loss: 1.7837
# Epoch 29/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.
2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9752 - loss: 0.0898 - val_accuracy: 0.9679 - val_loss: 0.1111
# Epoch 415/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9748 - loss: 0.0899 - val_accuracy: 0.9677 - val_loss: 0.1113
# Epoch 416/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9755 - loss: 0.0874 - val_accuracy: 0.9678 - val_loss: 0.1114
# Epoch 417/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9743 - loss: 0.0888 - val_accuracy: 0.9679 - val_loss: 0.1112
# Epoch 418/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9752 - loss: 0.0905 - val_accuracy: 0.9678 - val_loss: 0.1107
# Epoch 419/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9750 - loss: 0.0925 - val_accuracy: 0.9681 - val_loss: 0.1108
# Epoch 420/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9756 - loss: 0.0880 - val_accuracy: 0.9680 - val_loss: 0.1109
# Epoch 421/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9739 - loss: 0.0923 - val_accuracy: 0.9678 - val_loss: 0.1109
# Epoch 422/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9758 - loss: 0.0902 - val_accuracy: 0.9678 - val_loss: 0.1106
# Epoch 423/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9755 - loss: 0.0891 - val_accuracy: 0.9677 - val_loss: 0.1102
# Epoch 424/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9745 - loss: 0.0913 - val_accuracy: 0.9677 - val_loss: 0.1113
# Epoch 425/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9759 - loss: 0.0888 - val_accuracy: 0.9676 - val_loss: 0.1106
# Epoch 426/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9755 - loss: 0.0896 - val_accuracy: 0.9680 - val_loss: 0.1100
# Epoch 427/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9749 - loss: 0.0896 - val_accuracy: 0.9671 - val_loss: 0.1099
# Epoch 428/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9752 - loss: 0.0901 - val_accuracy: 0.9678 - val_loss: 0.1102
# Epoch 429/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9761 - loss: 0.0872 - val_accuracy: 0.9676 - val_loss: 0.1096
# Epoch 430/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9769 - loss: 0.0870 - val_accuracy: 0.9686 - val_loss: 0.1099
# Epoch 431/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9750 - loss: 0.0890 - val_accuracy: 0.9681 - val_loss: 0.1095
# Epoch 432/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9768 - loss: 0.0848 - val_accuracy: 0.9683 - val_loss: 0.1096
# Epoch 433/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9766 - loss: 0.0847 - val_accuracy: 0.9679 - val_loss: 0.1089
# Epoch 434/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9759 - loss: 0.0875 - val_accuracy: 0.9687 - val_loss: 0.1091
# Epoch 435/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9760 - loss: 0.0866 - val_accuracy: 0.9682 - val_loss: 0.1092
# Epoch 436/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9767 - loss: 0.0848 - val_accuracy: 0.9682 - val_loss: 0.1092
# Epoch 437/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9766 - loss: 0.0837 - val_accuracy: 0.9678 - val_loss: 0.1092

# %%
callbacks = [
keras.callbacks.ModelCheckpoint(filepath="model_at_epoch_{epoch}.keras"),
keras.callbacks.EarlyStopping(monitor="val_loss", patience=4),
]

# %%
import matplotlib.pyplot as plt
# Assuming ’history’ is the object returned by model.fit()
# Extracting training and validation loss
train_loss = history.history['loss']
val_loss = history.history['val_loss']
# Extracting training and validation accuracy (if metrics were specified)
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
# Plotting training and validation loss
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(range(1, len(train_loss) + 1), train_loss, label='Training Loss', color='blue')
plt.plot(range(1, len(val_loss) + 1), val_loss, label='Validation Loss', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
# Plotting training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(range(1, len(train_acc) + 1), train_acc, label='Training Accuracy', color='blue')
plt.plot(range(1, len(val_acc) + 1), val_acc, label='Validation Accuracy', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-2fc07163ce2d> in <cell line: 0>()
#       2 # Assuming ’history’ is the object returned by model.fit()
#       3 # Extracting training and validation loss
# ----> 4 train_loss = history.history['loss']
#       5 val_loss = history.history['val_loss']
#       6 # Extracting training and validation accuracy (if metrics were specified)
#
# NameError: name 'history' is not defined

# %%
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# 313/313 - 2s - 6ms/step - accuracy: 0.9650 - loss: 0.1166
# Test accuracy: 0.9650

# %%
# Predict on test data
predictions = model.predict(x_test)
# Convert predictions from probabilities to digit labels
predicted_labels = np.argmax(predictions, axis=1)
# Check the first prediction
print(f"Predicted label for first image: {predicted_labels[0]}")
print(f"True label for first image: {np.argmax(y_test[0])}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Predicted label for first image: 7
# True label for first image: 7

# %%
model.save('mnist_fully_connected_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import os
from sklearn.utils import shuffle
import numpy as np
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from PIL import Image # Import Pillow
# Define dataset paths
train_dir = "/content/DevanagariHandwrittenDigitDataset/Train"
test_dir = "/content/DevanagariHandwrittenDigitDataset/Test"
# Define image size
img_height, img_width = 28, 28
# Function to load images and labels using PIL
def load_images_from_folder(folder):
  images = []
  labels = []
  class_names = sorted(os.listdir(folder)) # Sorted class names (digit_0, digit_1, ...)
  class_map = {name: i for i, name in enumerate(class_names)} # Map class names to labels
  for class_name in class_names:
    class_path = os.path.join(folder, class_name)
    label = class_map[class_name]
    for filename in os.listdir(class_path):
      img_path = os.path.join(class_path, filename)
      # Load image using PIL
      img = Image.open(img_path).convert("L") # Convert to grayscale
      img = img.resize((img_width, img_height)) # Resize to (28,28)
      img = np.array(img) / 255.0 # Normalize pixel values to [0,1]
      images.append(img)
      labels.append(label)
  return np.array(images), np.array(labels)
# Load training and testing datasets
x_train, y_train = load_images_from_folder(train_dir)
x_test, y_test = load_images_from_folder(test_dir)
# Shuffle the training dataset
x_train, y_train = shuffle(x_train, y_train)

# Shuffle the testing dataset
x_test, y_test = shuffle(x_test, y_test)

# Reshape images for Keras input
x_train = x_train.reshape(-1, img_height, img_width, 1) # Shape (num_samples, 28, 28, 1)
x_test = x_test.reshape(-1, img_height, img_width, 1)
# One-hot encode labels
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)
# Print dataset shape
print(f"Training set: {x_train.shape}, Labels: {y_train.shape}")
print(f"Testing set: {x_test.shape}, Labels: {y_test.shape}")
# Visualize some images
plt.figure(figsize=(10, 4))
for i in range(10):
  plt.subplot(2, 5, i + 1)
  plt.imshow(x_train[i].reshape(28, 28), cmap='gray')
  plt.title(f"Label: {np.argmax(y_train[i])}")
  plt.axis("off")
plt.show()
# Out:
# Training set: (17000, 28, 28, 1), Labels: (17000, 10)
# Testing set: (3000, 28, 28, 1), Labels: (3000, 10)

# %%
x_train = x_train.reshape(-1, img_height, img_width, 1)

# %%
# Model parameters
import tensorflow as tf
from tensorflow import keras
num_classes = 10
input_shape = (28, 28, 1)
model = keras.Sequential(
  [
    keras.layers.Input(shape=input_shape),
    keras.layers.Flatten(), # Flatten the 28x28 image to a 784-dimensional vector
    keras.layers.Dense(64, activation="sigmoid"),
    keras.layers.Dense(128, activation="sigmoid"),
    keras.layers.Dense(256, activation="sigmoid"),
    keras.layers.Dense(num_classes, activation="softmax"),
  ]
)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)                  │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 64)                  │          50,240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 256)                 │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 10)                  │           2,570 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 94,154 (367.79 KB)
#  Trainable params: 94,154 (367.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Model parameters
import tensorflow as tf
from tensorflow import keras
num_classes = 10
input_shape = (28, 28, 1)
def build_functional_model():
  # Input layer
  inputs = keras.Input(shape=input_shape)
  # Flatten layer
  x = keras.layers.Flatten()(inputs)
  # Hidden layers
  x = keras.layers.Dense(64, activation="sigmoid")(x)
  x = keras.layers.Dense(128, activation="sigmoid")(x)
  x = keras.layers.Dense(256, activation="sigmoid")(x)
  # Output layer
  outputs = keras.layers.Dense(num_classes, activation="softmax")(x)
  # Create model
  model = keras.Model(inputs=inputs, outputs=outputs)
  return model
# Build the model
functional_model = build_functional_model()
functional_model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)           │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 64)                  │          50,240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 256)                 │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 10)                  │           2,570 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 94,154 (367.79 KB)
#  Trainable params: 94,154 (367.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
optimizer="sgd", # Stochastic Gradient Descent
loss="categorical_crossentropy", # Loss function for multi-class classification
metrics=["accuracy"] # Track accuracy during training
)

# %%
batch_size = 128
epochs = 300
# Callbacks
callbacks = [
keras.callbacks.ModelCheckpoint(filepath="model_at_epoch_{epoch}.keras"),
]
# Train the model with callbacks and validation split
history = model.fit(
x_train,
y_train,
batch_size=batch_size,
epochs=epochs,
validation_split=0.15,
callbacks=callbacks,
)
# Out:
# Epoch 1/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.1068 - loss: 2.3543 - val_accuracy: 0.0773 - val_loss: 2.3047
# Epoch 2/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0893 - loss: 2.3046 - val_accuracy: 0.1020 - val_loss: 2.3047
# Epoch 3/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1037 - loss: 2.3037 - val_accuracy: 0.1020 - val_loss: 2.3024
# Epoch 4/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0977 - loss: 2.3030 - val_accuracy: 0.1118 - val_loss: 2.3036
# Epoch 5/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1028 - loss: 2.3015 - val_accuracy: 0.1439 - val_loss: 2.3026
# Epoch 6/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1131 - loss: 2.3012 - val_accuracy: 0.1012 - val_loss: 2.3010
# Epoch 7/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1146 - loss: 2.3010 - val_accuracy: 0.1004 - val_loss: 2.2999
# Epoch 8/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1099 - loss: 2.2995 - val_accuracy: 0.1027 - val_loss: 2.3003
# Epoch 9/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1149 - loss: 2.2997 - val_accuracy: 0.1275 - val_loss: 2.2984
# Epoch 10/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1189 - loss: 2.2987 - val_accuracy: 0.1306 - val_loss: 2.2973
# Epoch 11/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1262 - loss: 2.2977 - val_accuracy: 0.1027 - val_loss: 2.2960
# Epoch 12/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1266 - loss: 2.2972 - val_accuracy: 0.2224 - val_loss: 2.2967
# Epoch 13/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1347 - loss: 2.2959 - val_accuracy: 0.1780 - val_loss: 2.2953
# Epoch 14/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1276 - loss: 2.2959 - val_accuracy: 0.1651 - val_loss: 2.2956
# Epoch 15/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1454 - loss: 2.2947 - val_accuracy: 0.1000 - val_loss: 2.2930
# Epoch 16/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1358 - loss: 2.2941 - val_accuracy: 0.1196 - val_loss: 2.2919
# Epoch 17/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1480 - loss: 2.2927 - val_accuracy: 0.1000 - val_loss: 2.2927
# Epoch 18/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1508 - loss: 2.2918 - val_accuracy: 0.1561 - val_loss: 2.2911
# Epoch 19/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1513 - loss: 2.2909 - val_accuracy: 0.1157 - val_loss: 2.2916
# Epoch 20/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1454 - loss: 2.2899 - val_accuracy: 0.1039 - val_loss: 2.2875
# Epoch 21/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1682 - loss: 2.2890 - val_accuracy: 0.1463 - val_loss: 2.2869
# Epoch 22/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1389 - loss: 2.2869 - val_accuracy: 0.1016 - val_loss: 2.2869
# Epoch 23/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1552 - loss: 2.2862 - val_accuracy: 0.1031 - val_loss: 2.2851
# Epoch 24/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1799 - loss: 2.2848 - val_accuracy: 0.2784 - val_loss: 2.2834
# Epoch 25/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1865 - loss: 2.2834 - val_accuracy: 0.1867 - val_loss: 2.2827
# Epoch 26/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2121 - loss: 2.2819 - val_accuracy: 0.1612 - val_loss: 2.2809
# Epoch 27/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1907 - loss: 2.2808 - val_accuracy: 0.2020 - val_loss: 2.2804
# Epoch 28/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2173 - loss: 2.2788 - val_accuracy: 0.1776 - val_loss: 2.2786
# Epoch 29/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2177 - loss: 2.2782 - val_accuracy: 0.3153 - val_loss: 2.2751
# Epoch 30/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2402 - loss: 2.2760 - val_accuracy: 0.1773 - val_loss: 2.2750
# Epoch 31/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2633 - loss: 2.2744 - val_accuracy: 0.3506 - val_loss: 2.2713
# Epoch 32/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2678 - loss: 2.2714 - val_accuracy: 0.2651 - val_loss: 2.2693
# Epoch 33/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2898 - loss: 2.2693 - val_accuracy: 0.4012 - val_loss: 2.2667
# Epoch 34/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2255 - loss: 2.2667 - val_accuracy: 0.2765 - val_loss: 2.2663
# Epoch 35/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2708 - loss: 2.2642 - val_accuracy: 0.2855 - val_loss: 2.2623
# Epoch 36/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3102 - loss: 2.2616 - val_accuracy: 0.3557 - val_loss: 2.2607
# Epoch 37/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3348 - loss: 2.2589 - val_accuracy: 0.3404 - val_loss: 2.2565
# Epoch 38/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3482 - loss: 2.2556 - val_accuracy: 0.3027 - val_loss: 2.2525
# Epoch 39/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3173 - loss: 2.2515 - val_accuracy: 0.4514 - val_loss: 2.2489
# Epoch 40/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3553 - loss: 2.2483 - val_accuracy: 0.5580 - val_loss: 2.2442
# Epoch 41/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3922 - loss: 2.2442 - val_accuracy: 0.2467 - val_loss: 2.2417
# Epoch 42/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3727 - loss: 2.2403 - val_accuracy: 0.4184 - val_loss: 2.2352
# Epoch 43/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3877 - loss: 2.2349 - val_accuracy: 0.5686 - val_loss: 2.2297
# Epoch 44/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4553 - loss: 2.2296 - val_accuracy: 0.3384 - val_loss: 2.2255
# Epoch 45/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3683 - loss: 2.2240 - val_accuracy: 0.2957 - val_loss: 2.2203
# Epoch 46/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3626 - loss: 2.2161 - val_accuracy: 0.5384 - val_loss: 2.2111
# Epoch 47/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4619 - loss: 2.2096 - val_accuracy: 0.3910 - val_loss: 2.2037
# Epoch 48/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3929 - loss: 2.2010 - val_accuracy: 0.4576 - val_loss: 2.1949
# Epoch 49/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4637 - loss: 2.1951 - val_accuracy: 0.3063 - val_loss: 2.1877
# Epoch 50/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4259 - loss: 2.1835 - val_accuracy: 0.5580 - val_loss: 2.1757
# Epoch 51/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4712 - loss: 2.1735 - val_accuracy: 0.4051 - val_loss: 2.1639
# Epoch 52/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4635 - loss: 2.1621 - val_accuracy: 0.4745 - val_loss: 2.1510
# Epoch 53/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4946 - loss: 2.1506 - val_accuracy: 0.5349 - val_loss: 2.1359
# Epoch 54/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4781 - loss: 2.1337 - val_accuracy: 0.4537 - val_loss: 2.1214
# Epoch 55/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4575 - loss: 2.1156 - val_accuracy: 0.6059 - val_loss: 2.1023
# Epoch 56/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5111 - loss: 2.0979 - val_accuracy: 0.4663 - val_loss: 2.0827
# Epoch 57/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4822 - loss: 2.0791 - val_accuracy: 0.4196 - val_loss: 2.0627
# Epoch 58/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4969 - loss: 2.0567 - val_accuracy: 0.4937 - val_loss: 2.0364
# Epoch 59/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4859 - loss: 2.0268 - val_accuracy: 0.5263 - val_loss: 2.0079
# Epoch 60/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4737 - loss: 2.0003 - val_accuracy: 0.5137 - val_loss: 1.9790
# Epoch 61/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5176 - loss: 1.9721 - val_accuracy: 0.4733 - val_loss: 1.9467
# Epoch 62/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4905 - loss: 1.9387 - val_accuracy: 0.4776 - val_loss: 1.9102
# Epoch 63/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5025 - loss: 1.9050 - val_accuracy: 0.5016 - val_loss: 1.8729
# Epoch 64/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5159 - loss: 1.8653 - val_accuracy: 0.4812 - val_loss: 1.8346
# Epoch 65/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5182 - loss: 1.8237 - val_accuracy: 0.5306 - val_loss: 1.7921
# Epoch 66/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5307 - loss: 1.7814 - val_accuracy: 0.4725 - val_loss: 1.7499
# Epoch 67/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5181 - loss: 1.7408 - val_accuracy: 0.5004 - val_loss: 1.7096
# Epoch 68/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5328 - loss: 1.6994 - val_accuracy: 0.5710 - val_loss: 1.6643
# Epoch 69/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5530 - loss: 1.6603 - val_accuracy: 0.5890 - val_loss: 1.6247
# Epoch 70/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5740 - loss: 1.6174 - val_accuracy: 0.5416 - val_loss: 1.5851
# Epoch 71/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5593 - loss: 1.5739 - val_accuracy: 0.6094 - val_loss: 1.5449
# Epoch 72/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6010 - loss: 1.5321 - val_accuracy: 0.5910 - val_loss: 1.5098
# Epoch 73/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5851 - loss: 1.4994 - val_accuracy: 0.6259 - val_loss: 1.4738
# Epoch 74/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6114 - loss: 1.4666 - val_accuracy: 0.6039 - val_loss: 1.4425
# Epoch 75/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6060 - loss: 1.4326 - val_accuracy: 0.6298 - val_loss: 1.4091
# Epoch 76/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6247 - loss: 1.4037 - val_accuracy: 0.6306 - val_loss: 1.3788
# Epoch 77/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6254 - loss: 1.3699 - val_accuracy: 0.6647 - val_loss: 1.3488
# Epoch 78/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6420 - loss: 1.3421 - val_accuracy: 0.6345 - val_loss: 1.3222
# Epoch 79/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6392 - loss: 1.3155 - val_accuracy: 0.6741 - val_loss: 1.2948
# Epoch 80/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6464 - loss: 1.2946 - val_accuracy: 0.6682 - val_loss: 1.2718
# Epoch 81/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6552 - loss: 1.2563 - val_accuracy: 0.6557 - val_loss: 1.2450
# Epoch 82/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6602 - loss: 1.2390 - val_accuracy: 0.6639 - val_loss: 1.2212
# Epoch 83/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6740 - loss: 1.2115 - val_accuracy: 0.6769 - val_loss: 1.1977
# Epoch 84/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6734 - loss: 1.1942 - val_accuracy: 0.7024 - val_loss: 1.1752
# Epoch 85/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6813 - loss: 1.1687 - val_accuracy: 0.6976 - val_loss: 1.1523
# Epoch 86/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.
300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9130 - loss: 0.2924 - val_accuracy: 0.9043 - val_loss: 0.3105
# Epoch 248/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9123 - loss: 0.2989 - val_accuracy: 0.9051 - val_loss: 0.3089
# Epoch 249/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9082 - loss: 0.2920 - val_accuracy: 0.9047 - val_loss: 0.3072
# Epoch 250/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9081 - loss: 0.2981 - val_accuracy: 0.9063 - val_loss: 0.3055
# Epoch 251/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9031 - loss: 0.3074 - val_accuracy: 0.9086 - val_loss: 0.3036
# Epoch 252/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9108 - loss: 0.2946 - val_accuracy: 0.9067 - val_loss: 0.3023
# Epoch 253/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9076 - loss: 0.2888 - val_accuracy: 0.9090 - val_loss: 0.3003
# Epoch 254/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9099 - loss: 0.2933 - val_accuracy: 0.9114 - val_loss: 0.2986
# Epoch 255/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9116 - loss: 0.2902 - val_accuracy: 0.9098 - val_loss: 0.2970
# Epoch 256/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9143 - loss: 0.2845 - val_accuracy: 0.9102 - val_loss: 0.2957
# Epoch 257/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9140 - loss: 0.2810 - val_accuracy: 0.9118 - val_loss: 0.2944
# Epoch 258/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9112 - loss: 0.2838 - val_accuracy: 0.9122 - val_loss: 0.2922
# Epoch 259/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9171 - loss: 0.2804 - val_accuracy: 0.9118 - val_loss: 0.2907
# Epoch 260/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9153 - loss: 0.2770 - val_accuracy: 0.9118 - val_loss: 0.2892
# Epoch 261/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9146 - loss: 0.2765 - val_accuracy: 0.9125 - val_loss: 0.2877
# Epoch 262/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9163 - loss: 0.2798 - val_accuracy: 0.9133 - val_loss: 0.2858
# Epoch 263/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9200 - loss: 0.2694 - val_accuracy: 0.9149 - val_loss: 0.2844
# Epoch 264/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9158 - loss: 0.2758 - val_accuracy: 0.9157 - val_loss: 0.2835
# Epoch 265/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9206 - loss: 0.2715 - val_accuracy: 0.9137 - val_loss: 0.2816
# Epoch 266/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9215 - loss: 0.2726 - val_accuracy: 0.9169 - val_loss: 0.2801
# Epoch 267/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9222 - loss: 0.2646 - val_accuracy: 0.9141 - val_loss: 0.2790
# Epoch 268/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9222 - loss: 0.2653 - val_accuracy: 0.9157 - val_loss: 0.2772
# Epoch 269/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9178 - loss: 0.2671 - val_accuracy: 0.9165 - val_loss: 0.2756
# Epoch 270/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9202 - loss: 0.2654 - val_accuracy: 0.9161 - val_loss: 0.2743
# Epoch 271/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9227 - loss: 0.2662 - val_accuracy: 0.9184 - val_loss: 0.2730
# Epoch 272/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9203 - loss: 0.2624 - val_accuracy: 0.9176 - val_loss: 0.2714
# Epoch 273/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9225 - loss: 0.2577 - val_accuracy: 0.9188 - val_loss: 0.2700
# Epoch 274/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9233 - loss: 0.2573 - val_accuracy: 0.9200 - val_loss: 0.2687
# Epoch 275/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9226 - loss: 0.2596 - val_accuracy: 0.9204 - val_loss: 0.2674
# Epoch 276/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9262 - loss: 0.2527 - val_accuracy: 0.9192 - val_loss: 0.2664
# Epoch 277/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9236 - loss: 0.2550 - val_accuracy: 0.9196 - val_loss: 0.2651
# Epoch 278/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9231 - loss: 0.2540 - val_accuracy: 0.9208 - val_loss: 0.2638
# Epoch 279/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9244 - loss: 0.2548 - val_accuracy: 0.9208 - val_loss: 0.2623
# Epoch 280/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9267 - loss: 0.2462 - val_accuracy: 0.9204 - val_loss: 0.2611
# Epoch 281/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9265 - loss: 0.2485 - val_accuracy: 0.9220 - val_loss: 0.2597
# Epoch 282/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9271 - loss: 0.2520 - val_accuracy: 0.9224 - val_loss: 0.2581
# Epoch 283/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9302 - loss: 0.2434 - val_accuracy: 0.9247 - val_loss: 0.2573
# Epoch 284/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9294 - loss: 0.2395 - val_accuracy: 0.9247 - val_loss: 0.2557
# Epoch 285/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9240 - loss: 0.2525 - val_accuracy: 0.9243 - val_loss: 0.2547
# Epoch 286/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9281 - loss: 0.2461 - val_accuracy: 0.9247 - val_loss: 0.2532
# Epoch 287/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9318 - loss: 0.2370 - val_accuracy: 0.9247 - val_loss: 0.2525
# Epoch 288/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9308 - loss: 0.2357 - val_accuracy: 0.9251 - val_loss: 0.2511
# Epoch 289/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9290 - loss: 0.2396 - val_accuracy: 0.9259 - val_loss: 0.2500
# Epoch 290/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9326 - loss: 0.2328 - val_accuracy: 0.9247 - val_loss: 0.2486
# Epoch 291/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9305 - loss: 0.2409 - val_accuracy: 0.9247 - val_loss: 0.2475
# Epoch 292/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9266 - loss: 0.2479 - val_accuracy: 0.9255 - val_loss: 0.2463
# Epoch 293/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9341 - loss: 0.2325 - val_accuracy: 0.9251 - val_loss: 0.2452
# Epoch 294/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9317 - loss: 0.2321 - val_accuracy: 0.9255 - val_loss: 0.2440
# Epoch 295/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9340 - loss: 0.2349 - val_accuracy: 0.9267 - val_loss: 0.2433
# Epoch 296/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9328 - loss: 0.2295 - val_accuracy: 0.9275 - val_loss: 0.2423
# Epoch 297/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9307 - loss: 0.2342 - val_accuracy: 0.9275 - val_loss: 0.2415
# Epoch 298/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9334 - loss: 0.2324 - val_accuracy: 0.9275 - val_loss: 0.2399
# Epoch 299/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9324 - loss: 0.2250 - val_accuracy: 0.9275 - val_loss: 0.2388
# Epoch 300/300
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9364 - loss: 0.2203 - val_accuracy: 0.9275 - val_loss: 0.2379

# %%
callbacks = [
  keras.callbacks.ModelCheckpoint(filepath="model_at_epoch_{epoch}.keras"),
  keras.callbacks.EarlyStopping(monitor="val_loss", patience=4),
]

# %%
import matplotlib.pyplot as plt
# Assuming ’history’ is the object returned by model.fit()
# Extracting training and validation loss
train_loss = history.history['loss']
val_loss = history.history['val_loss']
# Extracting training and validation accuracy (if metrics were specified)
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
# Plotting training and validation loss
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(range(1, len(train_loss) + 1), train_loss, label='Training Loss', color='blue')
plt.plot(range(1, len(val_loss) + 1), val_loss, label='Validation Loss', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
# Plotting training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(range(1, len(train_acc) + 1), train_acc, label='Training Accuracy', color='blue')
plt.plot(range(1, len(val_acc) + 1), val_acc, label='Validation Accuracy', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.tight_layout()
plt.show()

# %%
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# 94/94 - 1s - 16ms/step - accuracy: 0.9257 - loss: 0.2516
# Test accuracy: 0.9257

# %%
# Predict on test data
predictions = model.predict(x_test)
# Convert predictions from probabilities to digit labels
predicted_labels = np.argmax(predictions, axis=1)
# Check the first prediction
print(f"Predicted label for first image: {predicted_labels[0]}")
print(f"True label for first image: {np.argmax(y_test[0])}")
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# Predicted label for first image: 9
# True label for first image: 9
